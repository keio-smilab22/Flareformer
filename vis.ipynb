# %%
import matplotlib as mpl
import matplotlib.pyplot as plt


import matplotlib.pyplot as plt
# pyplotモジュールを"plt"という名前でインポートする

mm = [0.45874858, 0.63905215, 0.7794955, 0.90953135, 0.9648553, 1.084398, 1.108565, 1.1694925, 1.1772101, 1.1926134, 1.2063847, 1.2195259, 1.2261181, 1.2586548, 1.2496417, 1.2635118, 1.2558348, 1.3092883, 1.286418, 1.3831036, 1.3436925, 1.3528152, 1.3320383, 1.3726391, 1.3686732, 1.3673556, 1.3685046, 1.4128175, 1.3572574, 1.388751, 1.3607414, 1.389319, 1.3804727, 1.3908565]
sfm = [7.8198705, 7.3346295, 8.271565, 7.990701, 8.335599, 7.9137306, 8.836577, 7.900134, 8.256342, 8.366865, 8.164919, 7.7727165, 8.333839, 8.132641, 7.9584403, 8.055488, 8.420071, 8.638384, 8.10282, 8.1074295, 7.59077, 7.818636, 7.6664, 7.983858, 7.6124134, 7.558505, 8.039207, 8.071377, 8.642812, 8.9355545, 8.13034, 8.761185, 8.006474, 7.777858]
plt.plot(mm)
# plt.plot(sfm)

plt.title("mm")
plt.show()

# %%
plt.plot(sfm)
plt.title("sfm")
plt.show()
